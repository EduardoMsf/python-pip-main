# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.barplot(x=['A', 'B', 'C'], y=[1 ,2, 3])
plt.show()

# %%
sns.set(style='darkgrid', palette='dark', font='sans-serif', font_scale=1.5)
sns.barplot(x=['A', 'B', 'C'], y=[1 ,2, 3])
plt.show()
