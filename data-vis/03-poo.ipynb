# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5, 11)
y = x ** 2

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.5, 0.9])
axes.plot(x, y, 'r')
fig.show()
# Out:
# /var/folders/wl/rfz0jc0j0nl4cphm8zrwr9xr0000gp/T/ipykernel_90904/1232662972.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axes2 = fig.add_axes([0.2, 0.55, 0.4, 0.3])
axes.plot(x, y, 'r')
axes2.plot(y, x, 'b')
axes2.set_facecolor('gray')
fig.show()
# Out:
# /var/folders/wl/rfz0jc0j0nl4cphm8zrwr9xr0000gp/T/ipykernel_90904/3478046689.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
